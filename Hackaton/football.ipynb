# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect('soccer/database.sqlite')

# %%
players = pd.read_sql('select * from player', con)
match = pd.read_sql('select * from match', con)
teams = pd.read_sql('select * from Team', con)

# %%
teams.head()
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB

# %%
pd.options.display.max_columns = None

# %%
match.iloc[10000:10001, :]
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 10000  10001        7809       7809  2015/2016     14  2015-11-28 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 10000       2002215              9904              8234               4
#
#        away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 10000               0             1.0             2.0             4.0
#
#        home_player_X4  home_player_X5  home_player_X6  home_player_X7  \
# 10000             6.0             8.0             4.0             6.0
#
#        home_player_X8  home_player_X9  home_player_X10  home_player_X11  \
# 10000             3.0             5.0              7.0              5.0
#
#        away_player_X1  away_player_X2  away_player_X3  away_player_X4  \
# 10000             1.0             2.0             4.0             6.0
#
#        away_player_X5  away_player_X6  away_player_X7  away_player_X8  \
# ...

# %%
players.query('player_api_id == 303913')
# Out:
#         id  player_api_id  player_name  player_fifa_api_id  \
# 8112  8124         303913  Oliver Sorg              201016
#
#                  birthday  height  weight
# 8112  1990-05-29 00:00:00  175.26     152

# %%
players.query('player_api_id == 41087.0')
# Out:
#         id  player_api_id        player_name  player_fifa_api_id  \
# 9197  9211          41087  Ron-Robert Zieler              186148
#
#                  birthday  height  weight
# 9197  1989-02-12 00:00:00  187.96     183

# %%
mdf = match.loc[:,['home_team_api_id', 'home_player_1']]

# %%
import numpy as np

# %%
players.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
mdf[np.logical_not(mdf.home_player_1.isna())].head()
# Out:
#      home_team_api_id  home_player_1
# 144              9996        39890.0
# 145              8203        38327.0
# 146              9986        95597.0
# 148              9994        30934.0
# 149              8342        37990.0

# %%
tcdf = mdf[np.logical_not(mdf.home_player_1.isna())]

# %%
tcdf.merge(players, left_on = 'home_player_1', right_on = 'player_api_id').merge(teams, left_on='home_team_api_id', right_on = 'team_api_id')
# Out:
#        home_team_api_id  home_player_1   id_x  player_api_id      player_name  \
# 0                  9996        39890.0   6893          39890     Mark Volders
# 1                  9996       148308.0  10105         148308   Sven De Volder
# 2                  9996       148308.0  10105         148308   Sven De Volder
# 3                  9996       148308.0  10105         148308   Sven De Volder
# 4                  9996       148308.0  10105         148308   Sven De Volder
# 5                  9996       148308.0  10105         148308   Sven De Volder
# 6                  9997        39890.0   6893          39890     Mark Volders
# 7                  9997        39890.0   6893          39890     Mark Volders
# 8                  9997        37937.0   2466          37937  Davino Verhulst
# 9                  9997        37937.0   2466          37937  Davino Verhulst
# 10                 9997        37937.0   2466          37937  Davino Verhulst
# ...
